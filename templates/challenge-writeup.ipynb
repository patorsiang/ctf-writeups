# %% [markdown]
# # Challenge Name
#
# ## Metadata
#
# - Event:
# - Category:
# - Difficulty: Unknown
# - Status: TODO
# - Files:
# - Skills Learned:

# %% [markdown]
# ## Problem Summary
#
# Summarize what the challenge gives you and what it asks you to recover.

# %% [markdown]
# ## Observations
#
# Record the first signals: file types, source code clues, strings, network behavior, metadata, screenshots, or error messages.

# %%
# Put small inspection commands or parsing experiments here.
# Keep the final notebook ordered and reproducible.

# %% [markdown]
# ## What I Tried
#
# Document useful attempts, false starts, and why each step changed the direction of the solve.

# %% [markdown]
# ## Key Idea
#
# Explain the vulnerability, trick, encoding, or investigation pivot in one clear paragraph.

# %% [markdown]
# ## Solution Walkthrough
#
# Write the solve path so a beginner can follow it and a reviewer can verify it.

# %%
# Final solve code or command reproduction goes here.

# %% [markdown]
# ## Flag
#
# `flag{...}`

# %% [markdown]
# ## Lessons Learned
#
# - Add the reusable lesson that should transfer to future challenges.

# %% [markdown]
# ## References
#
# - Add references only when they actually helped.
